# %%
# %pip install yfinance==0.2.41
# %pip installcrewai==0.28.8
# %pip installlangchain==0.1.20
# %pip install'crewai[tools]'
# %pip installlangchain-openai==0.1.17
# %pip installlangchain-community==0.0.38
# %pip installduckduckgo_search==5.3.0
# Out:
# Requirement already satisfied: yfinance in d:\repos\projects\aiagent\.venv\lib\site-packages (0.2.41)
# Requirement already satisfied: pandas>=1.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in d:\repos\projects\aiagent\.venv\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in d:\repos\projects\aiagent\.venv\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.
# Collecting crewai
#   Using cached crewai-0.51.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (8.1.7)
# Collecting embedchain<0.2.0,>=0.1.114 (from crewai)
#   Using cached embedchain-0.1.121-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: instructor==1.3.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (1.3.3)
# Requirement already satisfied: json-repair<0.26.0,>=0.25.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (0.25.3)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: langchain<=0.3,>0.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (0.2.14)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (1.42.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (1.26.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (1.26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (2.8.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (1.0.1)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in d:\repos\projects\aiagent\.venv\lib\site-packages (from crewai) (2023.12.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from instructor==1.3.3->crewai) (3.10.5)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in d:\repos\projects\aiagent\.venv\lib\site-packages (from instructor==1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.5.0,>=0.4.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from instructor==1.3.3->crewai) (0.4.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from instructor==1.3.3->crewai) (2.20.1)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from instructor==1.3.3->crewai) (13.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from instructor==1.3.3->crewai) (8.5.0)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from instructor==1.3.3->crewai) (0.12.4)
# Requirement already satisfied: colorama in d:\repos\projects\aiagent\.venv\lib\site-packages (from click<9.0.0,>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.13.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.12.3)
# Collecting chromadb<0.5.0,>=0.4.24 (from embedchain<0.2.0,>=0.1.114->crewai)
#   Using cached chromadb-0.4.24-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: cohere<6.0,>=5.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (5.8.1)
# Collecting google-cloud-aiplatform<2.0.0,>=1.26.1 (from embedchain<0.2.0,>=0.1.114->crewai)
#   Using cached google_cloud_aiplatform-1.63.0-py2.py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.44)
# Collecting langchain-cohere<0.2.0,>=0.1.4 (from embedchain<0.2.0,>=0.1.114->crewai)
#   Using cached langchain_cohere-0.1.9-py3-none-any.whl.metadata (6.6 kB)
# Collecting langchain-community<0.3.0,>=0.2.6 (from embedchain<0.2.0,>=0.1.114->crewai)
#   Using cached langchain_community-0.2.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-openai<0.2.0,>=0.1.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.22)
# Requirement already satisfied: mem0ai<0.0.21,>=0.0.20 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.0.20)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (3.5.0)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.3.1)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (2.0.32)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain<=0.3,>0.2->crewai) (6.0.2)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.32 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain<=0.3,>0.2->crewai) (0.2.34)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain<=0.3,>0.2->crewai) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain<=0.3,>0.2->crewai) (0.1.101)
# Requirement already satisfied: numpy<2,>=1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain<=0.3,>0.2->crewai) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain<=0.3,>0.2->crewai) (2.32.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (0.27.0)
# Requirement already satisfied: sniffio in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (4.12.2)
# Requirement already satisfied: deprecated>=1.2.6 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (8.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.26.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (4.25.4)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai) (0.47b0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pydantic<3.0.0,>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.9.4)
# Requirement already satisfied: Mako in d:\repos\projects\aiagent\.venv\lib\site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai) (1.3.5)
# Requirement already satisfied: idna>=2.8 in d:\repos\projects\aiagent\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.13.3->crewai) (3.7)
# Requirement already satisfied: soupsieve>1.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain<0.2.0,>=0.1.114->crewai) (2.6)
# Requirement already satisfied: build>=1.0.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.112.1)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.30.6)
# Requirement already satisfied: pulsar-client>=3.1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.19.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.26.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.47b0)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.20.0)
# Requirement already satisfied: pypika>=0.48.9 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (6.4.3)
# Requirement already satisfied: grpcio>=1.58.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.65.5)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (4.2.0)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in d:\repos\projects\aiagent\.venv\lib\site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.10.7)
# Requirement already satisfied: boto3<2.0.0,>=1.34.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.35.2)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.9.5)
# Requirement already satisfied: httpx-sse==0.4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (2.32.0.20240712)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\repos\projects\aiagent\.venv\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.16.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.34.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.24.0)
# Requirement already satisfied: packaging>=14.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (24.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.12.5)
# Requirement already satisfied: shapely<3.0.0dev in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.0.6)
# Requirement already satisfied: cachetools in d:\repos\projects\aiagent\.venv\lib\site-packages (from gptcache<0.2.0,>=0.1.43->embedchain<0.2.0,>=0.1.114->crewai) (5.5.0)
# Requirement already satisfied: certifi in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai) (3.20.0)
# Collecting langchain-experimental>=0.0.6 (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai)
#   Using cached langchain_experimental-0.0.64-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas>=1.4.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (2.2.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.32->langchain<=0.3,>0.2->crewai) (1.33)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (2024.1)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (1.11.0)
# Requirement already satisfied: six>=1.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain<=0.3,>0.2->crewai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain<=0.3,>0.2->crewai) (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in d:\repos\projects\aiagent\.venv\lib\site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain<0.2.0,>=0.1.114->crewai) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from typer<1.0.0,>=0.9.0->instructor==1.3.3->crewai) (1.5.4)
# Requirement already satisfied: botocore<1.36.0,>=1.35.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.35.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.10.2)
# Requirement already satisfied: pyproject_hooks in d:\repos\projects\aiagent\.venv\lib\site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.38.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\repos\projects\aiagent\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.32->langchain<=0.3,>0.2->crewai) (3.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\repos\projects\aiagent\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.2.2)
# Requirement already satisfied: mdurl~=0.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (0.1.2)
# Requirement already satisfied: coloredlogs in d:\repos\projects\aiagent\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\repos\projects\aiagent\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (24.3.25)
# Requirement already satisfied: sympy in d:\repos\projects\aiagent\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.13.2)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.47b0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.47b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.47b0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.47b0)
# Requirement already satisfied: opentelemetry-util-http==0.47b0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.47b0)
# Requirement already satisfied: setuptools>=16.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (65.5.0)
# Requirement already satisfied: asgiref~=3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.8.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pandas>=1.4.3->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (2024.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (2.10.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.24.6)
# Requirement already satisfied: httptools>=0.5.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in d:\repos\projects\aiagent\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.23.0)
# Requirement already satisfied: websockets>=10.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (13.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from Mako->alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai) (2.1.5)
# Requirement already satisfied: h2<5,>=3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (4.1.0)
# Requirement already satisfied: filelock in d:\repos\projects\aiagent\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (2024.6.1)
# Requirement already satisfied: pywin32>=226 in d:\repos\projects\aiagent\.venv\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (306)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.6.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.3.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (4.0.0)
# Requirement already satisfied: pyreadline3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.4.1)
# Using cached crewai-0.51.1-py3-none-any.whl (133 kB)
# Using cached embedchain-0.1.121-py3-none-any.whl (210 kB)
# Using cached chromadb-0.4.24-py3-none-any.whl (525 kB)
# Using cached google_cloud_aiplatform-1.63.0-py2.py3-none-any.whl (5.2 MB)
# Using cached langchain_cohere-0.1.9-py3-none-any.whl (35 kB)
# Using cached langchain_community-0.2.12-py3-none-any.whl (2.3 MB)
# Using cached langchain_experimental-0.0.64-py3-none-any.whl (204 kB)
# Installing collected packages: google-cloud-aiplatform, chromadb, langchain-community, langchain-experimental, langchain-cohere, embedchain, crewai
# Successfully installed chromadb-0.4.24 crewai-0.51.1 embedchain-0.1.121 google-cloud-aiplatform-1.63.0 langchain-cohere-0.1.9 langchain-community-0.2.12 langchain-experimental-0.0.64
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in d:\repos\projects\aiagent\.venv\lib\site-packages (0.2.14)
# Requirement already satisfied: PyYAML>=5.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (3.10.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.32 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (0.2.34)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (0.1.101)
# Requirement already satisfied: numpy<2,>=1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in d:\repos\projects\aiagent\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.4.0)
# Requirement already satisfied: httpcore==1.* in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\repos\projects\aiagent\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.32->langchain) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: "'crewai[tools]'": Expected package name at the start of dependency specifier
#     'crewai[tools]'
#     ^
# Requirement already satisfied: langchain-openai in d:\repos\projects\aiagent\.venv\lib\site-packages (0.1.22)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.33 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-openai) (0.2.34)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-openai) (1.42.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (0.1.101)
# Requirement already satisfied: packaging<25,>=23.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.4.2)
# Requirement already satisfied: sniffio in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in d:\repos\projects\aiagent\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in d:\repos\projects\aiagent\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (3.7)
# Requirement already satisfied: certifi in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\repos\projects\aiagent\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.33->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.33->langchain-openai) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.33->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.33->langchain-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.2)
# Requirement already satisfied: colorama in d:\repos\projects\aiagent\.venv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.40.0->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-community in d:\repos\projects\aiagent\.venv\lib\site-packages (0.2.12)
# Requirement already satisfied: PyYAML>=5.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.13 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (0.2.14)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.30 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (0.2.34)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (0.1.101)
# Requirement already satisfied: numpy<2,>=1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain<0.3.0,>=0.2.13->langchain-community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain<0.3.0,>=0.2.13->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\repos\projects\aiagent\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\repos\projects\aiagent\.venv\lib\site-packages (from requests<3,>=2->langchain-community) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in d:\repos\projects\aiagent\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: anyio in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (4.4.0)
# Requirement already satisfied: httpcore==1.* in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.5)
# Requirement already satisfied: sniffio in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\repos\projects\aiagent\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\repos\projects\aiagent\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.30->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.13->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\repos\projects\aiagent\.venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.13->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\repos\projects\aiagent\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import os
from datetime import datetime
from crewai import Agent, Task, Crew, Process
from langchain.tools import Tool
from langchain_openai import ChatOpenAI
import yfinance as yf
from langchain_community.tools import DuckDuckGoSearchResults

# %%
def fetch_stock_price(ticket):
  stock = yf.download(ticket, start="2023-08-08", end="2024-08-08")
  return stock
yahoo_finance_tool = Tool(
  name="yahoo_finance",
  description="Fetch stock price from {tickets} from last year",
  func= lambda ticket: fetch_stock_price(ticket),
)

# %%
os.environ["OPENAI_API_KEY"] = ""
llm = ChatOpenAI(model="gpt-3.5-turbo")

# %%
stockPriceAnalyst = Agent(
  role="Senior stock price Analyst",
  goal="Find the {ticket} stock price history and create a trend analyses of up, down or sideways",
  backstory="""You are a highly experienced in analysing the price of an 
  specific stock and make predictions about its future price""",
  verbose=True,
  llm=llm,
  tools=[yahoo_finance_tool],
  memory=True,
  max_iter=5,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       1 stockPriceAnalyst = Agent(
#       2   role="Senior stock price Analyst",
#       3   goal="Find the {ticket} stock price history and create a trend analyses of up, down or sideways",
#       4   backstory="""You are a highly experienced in analysing the price of an
#       5   specific stock and make predictions about its future price""",
#       6   verbose=True,
# ----> 7   llm=llm,
#       8   tools=[yahoo_finance_tool],
#       9   memory=True,
#      10   max_iter=5,
#      11 )
#
# NameError: name 'llm' is not defined

# %%
getStockPrice = Task(
  name="Analyse the stock {ticket} price history and create a trend analyses of up, down or sideways",
  expected_output=""""Specify the current trend of the stock price - up, down or sideways,
  eg, stock= 'APPL, price UP'""""",
  description="Get stock price",
  agent=stockPriceAnalyst,
)

# %%
search_tool = DuckDuckGoSearchResults(backend='news', num_results=10)

# %%
newsAnalyst = Agent(
    role= "Stock News Analyst",
    goal="""Create a short summary of the market news related to the stock {ticket} company. Specify the current trend - up, down or sideways with
    the news context. For each request stock asset, specify a numbet between 0 and 100, where 0 is extreme fear and 100 is extreme greed.""",
    backstory="""You're highly experienced in analyzing the market trends and news and have tracked assest for more then 10 years.

    You're also master level analyts in the tradicional markets and have deep understanding of human psychology.

    You understand news, theirs tittles and information, but you look at those with a health dose of skepticism. 
    You consider also the source of the news articles. 
    """,
    verbose=True,
    llm= llm,
    max_iter= 10,
    memory= True,
    tools=[search_tool],
    allow_delegation=False
)

# %%
get_news = Task(
    description= f"""Take the stock and always include BTC to it (if not request).
    Use the search tool to search each one individually. 

    The current date is {datetime.now()}.

    Compose the results into a helpfull report""",
    expected_output = """"A summary of the overall market and one sentence summary for each request asset. 
    Include a fear/greed score for each asset based on the news. Use format:
    <STOCK ASSET>
    <SUMMARY BASED ON NEWS>
    <TREND PREDICTION>
    <FEAR/GREED SCORE>
""",
    agent= newsAnalyst
)

# %%
stockAnalystWrite = Agent(
    role = "Senior Stock Analyts Writer",
    goal= """"Analyze the trends price and news and write an insighfull compelling and informative 3 paragraph long newsletter based on the stock report and price trend. """,
    backstory= """You're widely accepted as the best stock analyst in the market. You understand complex concepts and create compelling stories
    and narratives that resonate with wider audiences. 

    You understand macro factors and combine multiple theories - eg. cycle theory and fundamental analyses. 
    You're able to hold multiple opinions when analyzing anything.
""",
    verbose = True,
    llm=llm,
    max_iter = 5,
    memory=True,
    allow_delegation = True
)

# %%
writeAnalyses = Task(
    description = """Use the stock price trend and the stock news report to create an analyses and write the newsletter about the {ticket} company
    that is brief and highlights the most important points.
    Focus on the stock price trend, news and fear/greed score. What are the near future considerations?
    Include the previous analyses of stock trend and news summary.
""",
    expected_output= """"An eloquent 3 paragraphs newsletter formated as markdown in an easy readable manner. It should contain:

    - 3 bullets executive summary 
    - Introduction - set the overall picture and spike up the interest
    - main part provides the meat of the analysis including the news summary and fead/greed scores
    - summary - key facts and concrete future trend prediction - up, down or sideways.
""",
    agent = stockAnalystWrite,
    context = [getStockPrice, get_news]
)

# %%
crew = Crew(
  agents= [stockPriceAnalyst, get_news, writeAnalyses],
  tasks= [getStockPrice, get_news, writeAnalyses],
  verbose= 2,
  process=Process.hierarchical,
  full_output= True,
  share_crew= False,
  manager_llm=llm,
  max_iter=15
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 crew = Crew(
# ----> 2   agents= [stockPriceAnalyst, get_news, writeAnalyses],
#       3   tasks= [getStockPrice, get_news, writeAnalyses],
#       4   verbose= 2,
#       5   process=Process.hierarchical,
#       6   full_output= True,
#       7   share_crew= False,
#       8   manager_llm=llm,
#       9   max_iter=15
#      10 )
#
# NameError: name 'stockPriceAnalyst' is not defined

# %%
results = crew.kickoff(inputs={'ticket': 'AAPL'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 results = crew.kickoff(inputs={'ticket': 'AAPL'})
#
# NameError: name 'crew' is not defined
